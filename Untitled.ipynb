# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

titanicdata= pd.read_csv("train.csv")

# %%
titanicdata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
electric= pd.read_csv("train_data.csv")

# %%
electric.head()
# Out:
#         T       V      P     RH        E
# 0  273.39  420.12  91.84  57.41  1778.12
# 1  195.26  248.88  92.29  35.21  1824.16
# 2  377.52  360.42  92.31  27.69  1761.72
# 3  171.60  244.98  91.61  56.99  1889.64
# 4  222.56  353.70  92.43  54.25  1806.68

# %%
electric.shape
# Out:
# (2000, 5)

# %%
electric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
# T     2000 non-null float64
# V     2000 non-null float64
# P     2000 non-null float64
# RH    2000 non-null float64
# E     2000 non-null float64
# dtypes: float64(5)
# memory usage: 78.2 KB

# %%
electric.isnull().sum()
# Out:
# T     0
# V     0
# P     0
# RH    0
# E     0
# dtype: int64

# %%
electric.hist(figsize=(12,8),bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002569E49B9E8>,
# ...
#       dtype=object)

# %%
sns.pairplot(electric)

# %%
co = electric.corr()

# %%
sns.heatmap(co, annot=True)

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
Y=electric[['E']]
X = electric.drop('E', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
scaler  = preprocessing.StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)

# %%
rescaledX
# Out:
# array([[-1.4052894 , -1.0197937 ,  2.88071705,  0.9864909 ],
#        [ 0.61685799,  0.67421169, -0.29522549, -0.40432983],
#        [-0.42252577, -1.08624061, -1.47697155,  0.56640627],
#        ...,
#        [-1.89869336, -0.67036112, -0.40601418,  1.53033019],
#        [-0.50610786, -0.76104161,  0.77573188, -2.08353299],
#        [-1.02916999, -0.99868703, -0.05518332,  0.80823877]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
for idx, col_name in enumerate(X.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for T is -0.5877873047218937
# The coefficient for V is -0.16708718411341963
# The coefficient for P is 1.865100421895898
# The coefficient for RH is -0.9658969960065947

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 1893.0817976711332

# %%
 y_predict = regression_model.predict(X_test)

# %%
 regression_model.score(X_test, y_test)
# Out:
# 0.9297494277250888

# %%
 from sklearn.metrics import  r2_score
print('Variance score: %.2f' % r2_score(y_test, y_predict))
# Out:
# Variance score: 0.93

# %%
regression_model.predict([[236.34, 406.26,91.32,52.36]])
# Out:
# array([[1806.02991047]])

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)

# %%
model = sm.OLS(y_train, X_train).fit()

# %%
predictions = model.predict(X_train)

# %%
print_model = model.summary()

# %%
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      E   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     4484.
# Date:                Mon, 04 Mar 2019   Prob (F-statistic):               0.00
# Time:                        01:17:27   Log-Likelihood:                -6033.0
# No. Observations:                1400   AIC:                         1.208e+04
# Df Residuals:                    1395   BIC:                         1.210e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1893.0818     99.972     18.936      0.000    1696.970    2089.194
# ...

# %%
loandata= pd.read_csv("LoanPred.csv")

# %%
loandata.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
sns.countplot(loandata['Loan_Status'],label="Count")

# %%
loandata.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loandata.isnull().any()
# Out:
# Loan_ID              False
# Gender                True
# Married               True
# Dependents            True
# Education            False
# Self_Employed         True
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount            True
# Loan_Amount_Term      True
# Credit_History        True
# Property_Area        False
# Loan_Status          False
# dtype: bool

# %%
loandata.boxplot(column='ApplicantIncome', by = 'Education')

# %%
loandata.boxplot(column='LoanAmount')

# %%
temp1 = loandata['Credit_History'].value_counts(ascending=True)
temp2 = loandata.pivot_table(values='Loan_Status',index=['Credit_History'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
print ('Frequency Table for Credit History:') 
print (temp1)

print ('\nProbility of getting loan for each Credit History class:')
print (temp2)
# Out:
# Frequency Table for Credit History:
# 0.0     89
# 1.0    475
# Name: Credit_History, dtype: int64
#
# Probility of getting loan for each Credit History class:
#                 Loan_Status
# Credit_History
# 0.0                0.078652
# 1.0                0.795789

# %%
temp3 = pd.crosstab(loandata['Credit_History'], loandata['Loan_Status'])
temp3.plot(kind='bar', stacked=True, color=['red','blue'], grid=False)

# %%
loandata.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loandata['LoanAmount'].fillna(loandata['LoanAmount'].mean(), inplace=True)

# %%
loandata['Self_Employed'].fillna('No',inplace=True)

# %%
loandata['Gender'].fillna(loandata['Gender'].mode()[0], inplace=True)
loandata['Married'].fillna(loandata['Married'].mode()[0], inplace=True)
loandata['Dependents'].fillna(loandata['Dependents'].mode()[0], inplace=True)
loandata['Loan_Amount_Term'].fillna(loandata['Loan_Amount_Term'].mode()[0], inplace=True)
loandata['Credit_History'].fillna(loandata['Credit_History'].mode()[0], inplace=True)

# %%
loandata.isnull().any()
# Out:
# Loan_ID              False
# Gender               False
# Married              False
# Dependents           False
# Education            False
# Self_Employed        False
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount           False
# Loan_Amount_Term     False
# Credit_History       False
# Property_Area        False
# Loan_Status          False
# dtype: bool

# %%
loandata.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
sex = pd.get_dummies(loandata["Gender"],drop_first=True)

# %%
married = pd.get_dummies(loandata["Married"],drop_first=True)

# %%
Education = pd.get_dummies(loandata["Education"],drop_first=True)

# %%
propArea = pd.get_dummies(loandata["Property_Area"],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Property_Area'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-64ba3f415f7e> in <module>
# ...

# %%
loanstatus = pd.get_dummies(loandata["Loan_Status"],drop_first=True)

# %%
loandata= pd.concat([loandata,sex,married,Education,propArea,loanstatus],axis=1)

# %%
loandata.drop(["Urban"],axis=1,inplace=True)

# %%
loandata.head()
# Out:
#   Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0             5849                0.0  146.412162
# 1          1             4583             1508.0  128.000000
# 2          0             3000                0.0   66.000000
# 3          0             2583             2358.0  120.000000
# 4          0             6000                0.0  141.000000
#
#    Loan_Amount_Term  Credit_History
# 0             360.0             1.0
# 1             360.0             1.0
# 2             360.0             1.0
# 3             360.0             1.0
# 4             360.0             1.0

# %%
loandata.head()
# Out:
#   Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0             5849                0.0  146.412162
# 1          1             4583             1508.0  128.000000
# 2          0             3000                0.0   66.000000
# 3          0             2583             2358.0  120.000000
# 4          0             6000                0.0  141.000000
#
#    Loan_Amount_Term  Credit_History  Male  Yes  Not Graduate  Semiurban  \
# 0             360.0             1.0     1    0             0          0
# 1             360.0             1.0     1    1             0          0
# 2             360.0             1.0     1    1             0          0
# 3             360.0             1.0     1    1             1          0
# 4             360.0             1.0     1    0             0          0
#
#    Urban  Yes  Y
# 0      1    0  1
# 1      0    0  0
# 2      1    1  1
# 3      1    0  1
# 4      1    0  1

# %%
slfempl = pd.get_dummies(loandata["Self_Employed"],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Self_Employed'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-9a2dbb5029a9> in <module>
# ...

# %%
loandata= pd.concat([loandata,sex,married,Education,propArea,slfempl,loanstatus],axis=1)

# %%
loandata.drop("Dependents",axis=1)
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# 5               5417             4196.0  267.000000             360.0
# 6               2333             1516.0   95.000000             360.0
# 7               3036             2504.0  158.000000             360.0
# 8               4006             1526.0  168.000000             360.0
# 9              12841            10968.0  349.000000             360.0
# 10              3200              700.0   70.000000             360.0
# 11              2500             1840.0  109.000000             360.0
# ...

# %%
x=loandata.drop("Y",axis=1)
y=loandata["Y"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-0b508b2e1562> in <module>
# ----> 1 logmodel.fit(X_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1283
#    1284         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1285                          accept_large_sparse=solver != 'liblinear')
#    1286         check_classification_targets(y)
#    1287         self.classes_ = np.unique(y)
#
# ...

# %%
from sklearn import tree

# %%
from sklearn.model_selection import GridSearchCV

# %%
titanicdata = pd.read_csv("train.csv")

# %%
titanicdata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
model = tree.DecisionTreeClassifier(criterion='gini')

# %%
titanicdata.dropna(inplace=True)

# %%
sex = pd.get_dummies(titanicdata["Sex"],drop_first=True)

# %%
embark = pd.get_dummies(titanicdata["Embarked"],drop_first=True)

# %%
titanicdata= pd.concat([titanicdata,sex,embark],axis=1)

# %%
titanicdata.drop(["Sex","Embarked","PassengerId","Name","Ticket"],axis=1,inplace=True)

# %%
x=titanicdata.drop("Survived",axis=1)
y=titanicdata["Survived"]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
titanicdata.head()
# Out:
#     Survived  Pclass   Age  Parch     Fare  male  Q  S
# 1          1       1  38.0      0  71.2833     0  0  0
# 3          1       1  35.0      0  53.1000     0  0  1
# 6          0       1  54.0      0  51.8625     1  0  1
# 10         1       3   4.0      1  16.7000     0  0  1
# 11         1       1  58.0      0  26.5500     0  0  1

# %%
titanicdata.drop(["Cabin","SibSp"],axis=1,inplace=True)

# %%
x=titanicdata.drop("Survived",axis=1)
y=titanicdata["Survived"]

# %%
x
# Out:
#      Pclass   Age  Parch      Fare  male  Q  S
# 1         1  38.0      0   71.2833     0  0  0
# 3         1  35.0      0   53.1000     0  0  1
# 6         1  54.0      0   51.8625     1  0  1
# 10        3   4.0      1   16.7000     0  0  1
# 11        1  58.0      0   26.5500     0  0  1
# 21        2  34.0      0   13.0000     1  0  1
# 23        1  28.0      0   35.5000     1  0  1
# 27        1  19.0      2  263.0000     1  0  1
# 52        1  49.0      0   76.7292     0  0  0
# 54        1  65.0      1   61.9792     1  0  0
# 62        1  45.0      0   83.4750     1  0  1
# 66        2  29.0      0   10.5000     0  0  1
# 75        3  25.0      0    7.6500     1  0  1
# 88        1  23.0      2  263.0000     0  0  1
# 92        1  46.0      0   61.1750     1  0  1
# 96        1  71.0      0   34.6542     1  0  0
# 97        1  23.0      1   63.3583     1  0  0
# 102       1  21.0      1   77.2875     1  0  1
# 110       1  47.0      0   52.0000     1  0  1
# ...
